# %%
import numpy as np
import pandas as pd
import xarray as xr
import hvplot.xarray
import hvplot.pandas
import datetime as dt
import cartopy.crs as ccrs
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c0ef193f-b89f-4359-9d24-bd770cf0292c" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
raven_back_trajectories = xr.open_dataset('/Users/vonw/data/raven/hysplit/raven_back_trajectories.nc')
raven_back_trajectories
# Out:
# <xarray.Dataset>
# Dimensions:                      (time: 1560, vertical_level: 19,
#                                   ref_time_along_trajectories: 121)
# Coordinates:
#   * time                         (time) datetime64[ns] 2024-05-15 ... 2024-07...
#   * ref_time_along_trajectories  (ref_time_along_trajectories) float64 0.0 .....
#   * vertical_level               (vertical_level) float64 100.0 ... 9.1e+03
# Data variables:
#     latitude                     (time, vertical_level, ref_time_along_trajectories) float64 ...
#     longitude                    (time, vertical_level, ref_time_along_trajectories) float64 ...
#     altitude                     (time, vertical_level, ref_time_along_trajectories) float64 ...
#     pressure                     (time, vertical_level, ref_time_along_trajectories) float64 ...
#     potential temperature        (time, vertical_level, ref_time_along_trajectories) float64 ...
# ...

# %%
longitude = raven_back_trajectories.longitude[:].values.reshape((1560*19,121))
latitude  = raven_back_trajectories.latitude[:].values.reshape((1560*19,121))
altitude  = raven_back_trajectories.altitude[:].values.reshape((1560*19,121))

pressure  = raven_back_trajectories.pressure[:].values.reshape((1560*19,121))
potential_temperature = raven_back_trajectories['potential temperature'][:].values.reshape((1560*19,121))
air_temperature = raven_back_trajectories['air temperature'][:].values.reshape((1560*19,121))
rainfall = raven_back_trajectories.rainfall[:].values.reshape((1560*19,121))
mix_depth = raven_back_trajectories['mix depth'][:].values.reshape((1560*19,121))
relative_humidity = raven_back_trajectories['relative humidity'][:].values.reshape((1560*19,121))
terrain_above_msl = raven_back_trajectories['terrain above msl'][:].values.reshape((1560*19,121))
solar_flux = raven_back_trajectories['solar flux'][:].values.reshape((1560*19,121))

# %%
reftime = []
for t in raven_back_trajectories.time.values:
    for n in range(19):
        for dt in raven_back_trajectories.ref_time_along_trajectories.values:
            reftime.append(t + pd.Timedelta(dt, unit='hours'))
reftime = np.array(reftime).reshape((1560*19,121))

# %%
ds = xr.Dataset({'potential temperature': ['time', 'longitude', ]})

# %% [markdown]
# Now create a new dataset with geophysical variables that have dimensions (time,latitude,longitude,altitude)
